# %%
board = [["5","3",".",".","7",".",".",".","."],["6",".",".","1","9","5",".",".","."],[".","9","8",".",".",".",".","6","."],["8",".",".",".","6",".",".",".","3"],["4",".",".","8",".","3",".",".","1"],["7",".",".",".","2",".",".",".","6"],[".","6",".",".",".",".","2","8","."],[".",".",".","4","1","9",".",".","5"],[".",".",".",".","8",".",".","7","9"]]
expanded_list = []

class Board:
    def __init__(self,board):
        self.board = board
        self.digits = ["1","2","3","4","5","6","7","8","9"]
        self.counts = {i:0 for i in self.digits}
        self.expanded_list = self.build_expanded_list()
        
    
    def build_expanded_list(self):
        expanded_list = []
        for row in board:
            for i in row:
                expanded_list.append(i)
                if i!=".":
                    self.counts[i] += 1
        return expanded_list
    
    def block(self,i):
        column = i%9
        row = i//9
        return column//3 + 3*(row//3)
    
    def row(self,i):
        return i//9

    def col(self,i):
        return i%9

    def already_in_row(self, row=0, num=1):
        for k in [self.expanded_list[j] for j in range(9*(row),9*((row)+1))]:
            if k==f'{num}':
                return True
        return False    
    
    def already_in_col(self, col=0, num=1):
        for k in [self.expanded_list[j] for j in range((col),len(self.expanded_list),9)]:
            if k==f'{num}':
                return True
        return False

    def already_in_block(self, block_num, num=1):
        block_row = block_num // 3
        block_col = block_num % 3

        for r in range(block_row * 3, block_row * 3 + 3):
            for c in range(block_col * 3, block_col * 3 + 3):
                if self.expanded_list[r * 9 + c] == str(num):
                    return True
        return False
    
    def candidates(self,i):
        return [j for j in self.digits if not self.already_in_row(self.row(i),num=j) and not self.already_in_col(self.col(i), num=j) and not self.already_in_block(self.block(i),num=j)]
    
    def solve_row(self, row):
        for i in range(0,len(row)):
            try:
                i = self.candidates(9*row+i)[0]
            except:
                return None
    
    def solve_col(self,col):
        for i in range(0,len(col)):
            try:
                i = self.candidates(col+i*9)[0]
            except:
                return None
    
    def solve_block(self,block):

# %%
board = Board(board)

# %%
board.block(11)
# Out:
# 0

# %%
board.already_in_row(num=1)
# Out:
# False

# %%
board.already_in_col(col=1,num=2)
# Out:
# False

# %%
board.already_in_block(block_num=0,num=6)
# Out:
# True

# %%
board.candidates(3)
# Out:
# ['2', '6']
